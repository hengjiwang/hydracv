# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.abspath(''), '.')))

from cv2 import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd
from scipy.io import loadmat

# %%
ecto_fluo = pd.read_csv("./data/fluorescence/friday-200um-1_6-1_0_ecto.csv").values
endo_fluo = pd.read_csv("./data/fluorescence/friday-200um-1_6-1_0_endo.csv").values
plt.figure(figsize=(20,3))
plt.plot(ecto_fluo[:-1, 0], 'g', linewidth=1)
plt.plot(endo_fluo[:-1, 0], 'r', linewidth=1)
plt.show()

# %%
tr = loadmat("./data/fluorescence/5hz2bin_traces.mat")
ecto_fluo = tr['traces'][:, 1]
endo_fluo = tr['traces'][:, 0]
plt.figure(figsize=(20,3))
plt.plot(ecto_fluo[:], 'g')
plt.plot(endo_fluo[:], 'r')
# plt.plot(ecto_fluo[11000:12000], 'g')
# plt.plot(endo_fluo[11000:12000], 'r')
plt.show()

# %%
tr = loadmat("./data/fluorescence/gemini-overnight-overnight2.mat")
ecto_fluo = tr['traces'][:, 1]
endo_fluo = tr['traces'][:, 0]
plt.figure(figsize=(20,3))
plt.plot(ecto_fluo[:1000], 'g')
plt.plot(endo_fluo[:1000], 'r')
plt.show()

# %%
ecto_fluo = pd.read_csv("./data/fluorescence/solamere_ecto.csv").values
endo_fluo = pd.read_csv("./data/fluorescence/solamere_endo.csv").values
plt.figure(figsize=(20,3))
plt.plot(ecto_fluo[:-1, 0], 'g', linewidth=1)
plt.plot(endo_fluo[:-1, 0], 'r', linewidth=1)
plt.show()

# %%
ecto_fluo = pd.read_csv("./data/fluorescence/DynWat_16X_Animal16_30mins_ecto.csv").values
endo_fluo = pd.read_csv("./data/fluorescence/DynWat_16X_Animal16_30mins_endo.csv").values
plt.figure(figsize=(20,3))
plt.plot(ecto_fluo[3090:-1, 2], 'g', linewidth=1)
plt.plot(endo_fluo[3090:-1, 2], 'r', linewidth=1)
# plt.plot(ecto_fluo[3590:4000, 2], 'g', linewidth=1)
# plt.plot(endo_fluo[3590:4000, 2], 'r', linewidth=1)
plt.show()

# %%
ecto_fluo = pd.read_csv("./data/fluorescence/DynWat_16X_Animal14_30mins_ecto.csv").values
endo_fluo = pd.read_csv("./data/fluorescence/DynWat_16X_Animal14_30mins_endo.csv").values
plt.figure(figsize=(20,3))
plt.plot(ecto_fluo[3080:-1, 2], 'g', linewidth=1)
plt.plot(endo_fluo[3080:-1, 2], 'r', linewidth=1)
plt.show()

# %%
ecto_fluo = pd.read_csv("./data/fluorescence/DynWat_16X_Animal15_30mins_ecto.csv").values
endo_fluo = pd.read_csv("./data/fluorescence/DynWat_16X_Animal15_30mins_endo.csv").values
plt.figure(figsize=(20,3))
plt.plot(ecto_fluo[3090:-1, 2], 'g', linewidth=1)
plt.plot(endo_fluo[3090:-1, 2], 'r', linewidth=1)
plt.show()
