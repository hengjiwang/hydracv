# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.abspath(''), '..')))

import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import pandas as pd

import hydracv.utils.utils as utils
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
legnths = utils.length_of_model("./data/model_length/coords_579123.txt")

# %%
legnths = utils.length_of_model("./data/model_length/coords_long_thin.txt", totaltime=100, loc='y')

# %%
legnths = utils.length_of_model("./data/model_length/coords_579123_k7_05.txt")

# %%
lengths_1 = utils.length_of_model("./data/model_length/coords_119358.txt")

# %%
lengths_2 = utils.length_of_model("./data/model_length/coords_119358_v200.txt", totaltime=200)

# %%
lengths_3 = utils.length_of_model("./data/model_length/coords_119358_v500.txt", totaltime=200)

# %%
lengths_4 = utils.length_of_model("./data/model_length/coords_119358_v1000.txt", totaltime=200)

# %%
plt.figure()
time_axis = np.arange(0, 200.1, 0.1)
plt.plot(time_axis, lengths_1[:2001], label='relax_time=100s')
plt.plot(time_axis, lengths_2, label='relax_time=200s')
plt.plot(time_axis, lengths_3, label='relax_time=500s')
plt.plot(time_axis, lengths_4, label='relax_time=1000s')
plt.legend()
plt.show()
